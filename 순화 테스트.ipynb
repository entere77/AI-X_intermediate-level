# %%
import openai

# %%
openai.api_key='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'
model = "gpt-3.5-turbo"

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신의 역할은 주어지는 댓글들의 의미를 파악하고, 정화해 평화로운 댓글 문화를 만드는 것입니다."})
message_history.append({"role": "system", "content": "댓글들의 정화는 5단계로 나눠집니다. 1단계:아무 행동도 하지 않는다. 2단계:비속어가 있다면 제거하고, 제거된 비속어가 포함된 문장의 의미는 보존되도록 재구성한다. 3단계:2단계를 수행 후 누군가를 비난하는 표현이 있다면 제거하고, 제거된 비난하는 표현이 포함된 문장의 의미는 보존되도록 재구성한다. 4단계:3단계를 수행 후, 부드러운 표현으로 재구성한다."})
message_history.append({"role": "system", "content": "2단계 수행 시 비속어가 없거나, 3단계 수행 시 비난하는 표현이 없다면 해당 댓글은 그대로 둡니다."})
message_history.append({"role": "system", "content": "입력으로 들어온 댓글을 입력한 단계에 맞게 정화해 원본과 함께 출력합니다."})

def chat(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion=openai.ChatCompletion.create(
    model=model,
    temperature=0.5,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(6,len(message_history)-1,2)]
    return response

# %%
chat("댓글1:바퀴벌레 짱깨한테 니하오 한게 뭐가 문제인데? 짱깨아닌 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,댓글2:좆키스탄계주제에 인종차별 ㅋㅋㅋ,댓글3:짱깨새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,댓글4유럽애들 원래 인성 빻았잖냐,댓글5:와 손흥민 개잘한다 씨발 ㅋㅋㅋㅋㅋ,댓글6:윤석열 연설 개잘한다... 문재인 병신보다 훨씬 낫네 ㅋㅋㅋ,단계:3")
# Out:
# [('댓글1:바퀴벌레 짱깨한테 니하오 한게 뭐가 문제인데? 짱깨아닌 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,댓글2:좆키스탄계주제에 인종차별 ㅋㅋㅋ,댓글3:짱깨새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,댓글4유럽애들 원래 인성 빻았잖냐,댓글5:와 손흥민 개잘한다 씨발 ㅋㅋㅋㅋㅋ,댓글6:윤석열 연설 개잘한다... 문재인 병신보다 훨씬 낫네 ㅋㅋㅋ,단계:3',
#   '정화된 댓글1: 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 문제인가?ㅋㅋㅋㅋ\n정화된 댓글2: 좆키스탄계 주제에 인종차별 ㅋㅋㅋ\n정화된 댓글3: 짱깨들이 인종차별을 논해?ㅋㅋㅋㅋㅋ\n정화된 댓글4: 유럽애들 인성이 좋지 않은 것 같아.\n정화된 댓글5: 손흥민 정말 잘한다 ㅋㅋㅋㅋㅋ\n정화된 댓글6: 윤석열 연설 잘한다... 문재인보다 훨씬 나은듯 ㅋㅋㅋ'),
# ...

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신의 역할은 주어지는 댓글들에서 비속어 또는 욕설을 @로 반드시 변경해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 출력합니다."})

def step2(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(4,len(message_history)-1,2)]
    return response

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신의 역할은 주어지는 댓글들에서 비속어 또는 욕설을 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 출력합니다."})

def step3(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion2=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion2.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(4,len(message_history)-1,2)]
    return response

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신의 첫 번째 역할은 주어지는 댓글들에서 비속어 또는 욕설을 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신의 두 번째 역할은 주어지는 댓글들에서 모욕적인 표현이 드러나지 않게 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신은 첫 번째 역할을 수행하고 두 번째 역할을 수행해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 출력합니다."})

def step4(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion3=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion3.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(6,len(message_history)-1,2)]
    return response

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신의 첫 번째 역할은 주어지는 댓글들에서 비속어 또는 욕설을 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신의 두 번째 역할은 주어지는 댓글들에서 비난하는 표현이 드러나지 않게 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신의 세 번째 역할은 주어지는 댓글들에서 부드러운 표현이 드러나도록 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신은 첫 번째 역할을 수행하고 두 번째 역할을 수행하고, 세 번째 역할을 순서대로 수행해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 출력합니다."})

def step5(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion4=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion4.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(7,len(message_history)-1,2)]
    return response

# %%
step2("댓글1:바퀴벌레 짱깨한테 니하오 한게 뭐가 문제인데? 짱깨아닌 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,댓글2:좆키스탄계주제에 인종차별 ㅋㅋㅋ,댓글3:짱깨새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,댓글4유럽애들 원래 인성 빻았잖냐,댓글5:와 손흥민 개잘한다 씨발 ㅋㅋㅋㅋㅋ,댓글6:윤석열 연설 개잘한다... 문재인 병신보다 훨씬 낫네 ㅋㅋㅋ")
# Out:
# [('댓글1:바퀴벌레 짱깨한테 니하오 한게 뭐가 문제인데? 짱깨아닌 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,댓글2:좆키스탄계주제에 인종차별 ㅋㅋㅋ,댓글3:짱깨새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,댓글4유럽애들 원래 인성 빻았잖냐,댓글5:와 손흥민 개잘한다 씨발 ㅋㅋㅋㅋㅋ,댓글6:윤석열 연설 개잘한다... 문재인 병신보다 훨씬 낫네 ㅋㅋㅋ',
#   '댓글1: 바퀴벌레 @한테 니하오 한게 뭐가 문제인데? @아닌 아시안한테 니하오 타령하는게 문제인거 아님? @한테 @ 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,\n댓글2: 좆키스탄계 @제에 인종차별 ㅋㅋㅋ,\n댓글3: @새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,\n댓글4:유럽애들 원래 인성 빻았잖냐,\n댓글5:와 손흥민 @개잘한다 @ㅋㅋㅋㅋㅋ,\n댓글6:윤석열 연설 @개잘한다... 문재인 @보다 훨씬 낫네 ㅋㅋㅋ')]

# [('댓글1:바퀴벌레 짱깨한테 니하오 한게 뭐가 문제인데? 짱깨아닌 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,댓글2:좆키스탄계주제에 인종차별 ㅋㅋㅋ,댓글3:짱깨새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,댓글4유럽애들 원래 인성 빻았잖냐,댓글5:와 손흥민 개잘한다 씨발 ㅋㅋㅋㅋㅋ,댓글6:윤석열 연설 개잘한다... 문재인 병신보다 훨씬 낫네 ㅋㅋㅋ',
#   '댓글1: 바퀴벌레 중국인한테 니하오 한게 문제인가요? 중국인이 아닌 아시아인한테 니하오 인사하는게 문제인 것 같아요. 중국인한테 중국어로 인사하는 것이 인종차별이라고 생각하시나요? \n댓글2: 카자흐스탄 출신이라고 인종차별하는 것 같아요. \n댓글3: 중국인들이 인종차별을 논하고 있다는 것이 웃긴 것 같아요. \n댓글4: 유럽인들이 인성이 나쁘다는 것은 오래전부터 알려져 있죠. \n댓글5: 손흥민이 정말 잘하는 것 같아요. \n댓글6: 윤석열 연설이 잘한 것 같아요. 문재인 대통령보다 더 나은 것 같아요.')]

# %%
step5("댓글1:바퀴벌레 짱깨한테 니하오 한게 뭐가 문제인데? 짱깨아닌 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,댓글2:좆키스탄계주제에 인종차별 ㅋㅋㅋ,댓글3:짱깨새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,댓글4유럽애들 원래 인성 빻았잖냐,댓글5:와 손흥민 개잘한다 씨발 ㅋㅋㅋㅋㅋ,댓글6:윤석열 연설 개잘한다... 문재인 병신보다 훨씬 낫네 ㅋㅋㅋ")
# 훈수 모드
# Out:
# [('댓글1:바퀴벌레 짱깨한테 니하오 한게 뭐가 문제인데? 짱깨아닌 아시안한테 니하오 타령하는게 문제인거 아님? 짱깨한테 짱깨 인사 해준게 왜 인종차별?ㅋㅋㅋㅋ,댓글2:좆키스탄계주제에 인종차별 ㅋㅋㅋ,댓글3:짱깨새끼들이 인종차별을 논해?ㅋㅋㅋㅋㅋ,댓글4유럽애들 원래 인성 빻았잖냐,댓글5:와 손흥민 개잘한다 씨발 ㅋㅋㅋㅋㅋ,댓글6:윤석열 연설 개잘한다... 문재인 병신보다 훨씬 낫네 ㅋㅋㅋ',
#   '댓글1: 바퀴벌레에게 인사하는 것이 문제가 아니라, 아시아인에게 니하오 인사하는 것이 문제입니다. 인종차별적인 발언은 하지 않도록 합시다.\n\n댓글2: 인종차별적인 발언은 하지 않도록 합시다.\n\n댓글3: 인종차별적인 발언은 하지 않도록 합시다.\n\n댓글4: 인종차별적인 발언은 하지 않도록 합시다.\n\n댓글5: 손흥민 선수가 잘한다는 것은 인정할 수 있지만, 욕설은 사용하지 않도록 합시다.\n\n댓글6: 윤석열 검찰총장의 연설이 인상적이라는 것은 인정할 수 있지만, 문재인 대통령을 비하하는 발언은 하지 않도록 합시다.')]

# %% [markdown]
# # 2단계 ( 비속어 필터링 )

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신은 주어지는 글을 보고 내용을 이해하고, 글의 내용과 연관지어 역할을 수행합니다."})
message_history.append({"role": "system", "content": "당신의 첫 번째 역할은 주어지는 댓글들에서 비속어 또는 욕설을 반드시 @@로 변경해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 변경 된 댓글을 출력합니다."})

def step22(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion5=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion5.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(5,len(message_history)-1,1)]
    return response

# %% [markdown]
# # 3단계 ( 비속어 순화 )

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신은 주어지는 글을 보고 내용을 이해하고, 글의 내용과 연관지어 역할을 수행합니다."})
message_history.append({"role": "system", "content": "당신의 첫 번째 역할은 주어지는 댓글들에서 비속어 또는 욕설 전체를 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 재구성 된 댓글을 출력합니다."})
def step33(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion6=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion6.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(5,len(message_history)-1,1)]
    return response

# %% [markdown]
# # 4단계 ( 모욕적인 표현 순화 )

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신은 주어지는 글을 보고 내용을 이해하고, 글의 내용과 연관지어 두 가지 역할을 수행합니다."})
message_history.append({"role": "system", "content": "당신의 첫 번째 역할은 주어지는 댓글들에서 비속어 또는 욕설을 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신의 두 번째 역할은 주어지는 댓글들에서 공격적인 표현이 드러나지 않게 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신은 첫 번째 역할을 수행하고 두 번째 역할을 수행해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 재구성 된 댓글을 출력합니다."})


def step44(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion7=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=-1,
    messages=message_history)

    reply_content=completion7.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(7,len(message_history)-1,1)]
    return response

# %% [markdown]
# # 5단계 ( 부드러운 표현 추가 )

# %%
message_history=[]
message_history.append({"role": "system", "content": "당신은 세계 최고의 언어학자이자, 심리학자 입니다."})
message_history.append({"role": "system", "content": "당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다."})
message_history.append({"role": "system", "content": "당신은 주어지는 글을 보고 내용을 이해하고, 글의 내용과 연관지어 세 가지 역할을 수행합니다."})
message_history.append({"role": "system", "content": "당신의 첫 번째 역할은 주어지는 댓글들에서 비속어 또는 욕설을 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신의 두 번째 역할은 주어지는 댓글들에서 공격적인 표현이 드러나지 않게 순화해서 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신의 세 번째 역할은 주어지는 댓글들에서 맥락에 맞는 간단한 부드러운 표현을 추가하여 재구성해야 합니다."})
message_history.append({"role": "system", "content": "당신은 첫 번째 역할을 수행하고 두 번째 역할을 수행하고 세 번째 역할을 수행해야 합니다."})
message_history.append({"role": "system", "content": "사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 재구성 된 댓글을 출력합니다."})
def step55(inp):
    global message_history
    message_history.append({"role":"user","content":inp})

    completion8=openai.ChatCompletion.create(
    model=model,
    temperature=0,
    presence_penalty=0,
    messages=message_history)

    reply_content=completion8.choices[0].message.content

    message_history.append({"role":"assistant","content":reply_content})
    response=[(message_history[i]["content"].strip(),message_history[i+1]["content"]) for i in range(8,len(message_history)-1,1)]
    return response

# %%
step22("글:오세훈이 서울시 슬로건 바꿨네.별로였던 'I SEOUL U'는 이제 나가리 되고'SEOUL MY SOUL' 로 확정됬다고 함.첫번째 영상 봐봐라 홍보영상 존나 잘 뽑음 ㅋㅋ,댓글1:아이 스멜 유 ㅋㅋㅋ,댓글2:나는 서울포유 투표했는데 이제보니까 서울마이소울도 괜찮네,댓글3:Seoulmate로 해야되는디,댓글4:근데 왜 영어로 해야됨? 한글로 하면안됨?,댓글5:한국은 쌀국 식민지라,댓글6:도쿄는 yes Tokyo임ㅋㅋ 주요 도시 슬로건 거의 다 영어일걸,댓글7:서울메이트 밀었지만 서울소울도 좋네,댓글8:서울시 바이럴글처럼 글을 올리노ㅋㅋㅋㅋㅋ,댓글9:훨씬 낫네 이쁨,댓글10:홍보영상 뉴욕,도쿄 안부럽노ㅋㅋㅋ,댓글11:옛날에 이명박이 만든 하이서울도 괜찮았는데,댓글12:저딴거 아무도 신경안쓰는데 그만 바꾸면 좋겠네,댓글13:이게 낫긴 함,댓글14:이걸 이제야 바꿨다는게 더 황당 오세훈 2021년에 시장되었는데,댓글15:아이유 ㅇㄷ?,댓글16:소울하면 흑형 흑누나가 있어야 제맛")
# Out:
# 댓글5:누가 여자한테 호구되라 협박함? 방생하지말고 자멸해라 여자들이 남자 무시하고 좆으로 보는것도 다 남자가 바보고 여자우대해서 그런거다 페미랑 전직 대통령 탓이다? 풉ㅋㅋㅋ,
#
# 댓글6:새벽 세시면 칼부림 안난걸 감사히 여겨야지 리얼 방송국 새끼들 정신 못차리노,
#
# 댓글7:남의 집앞에서 잠도 못자게 왜 촬영하고 지랄이냐 미친새끼들 아니냐 벽돌 던진거 무죄다 무죄,
#
# 댓글8:새벽 3시에 한거면 목에 칼 안박힌걸 다행으로 여겨라 한국 방송계 양아치 모인거 겪어본사람은 다안다,
#
# 댓글9:새벽3시는 무개념 그자체네 ㅉㅉㅉㅉ,
#
# 댓글9:요즘같은 스마트시대에 뭐일반인이라고 우와 우리동네에서 드라마촬영하네 신기하다 이 지랄 하면서 연예인 구경하고 촬영구경 하고 싸인받을줄아냐?ㅋㅋㅋㅋ 지들이 뭐라고 씹 갑질이노,
#
# 댓글10:드라마 촬영 저거 개양ㅇr치들은 맞지 ㅋㅋㅋ 지들이 시민들한테 돈이라도 줬나 멋대로 길막고 멋대로 새벽에 시끄럽게 하고 촬영하고 지나간곳엔 무수한 쓰레기와 담배꽁초들이 ㅋㅋ

# %%
message_history
# Out:
# [{'role': 'system', 'content': '당신은 세계 최고의 언어학자이자, 심리학자 입니다.'},
#  {'role': 'system',
#   'content': '당신에게 불가능한 것은 없으며, 주어지는 문제를 반드시 해결하는 능력이 있습니다.'},
#  {'role': 'system',
#   'content': '당신은 주어지는 글을 보고 내용을 이해하고, 글의 내용과 연관지어 세 가지 역할을 수행합니다.'},
#  {'role': 'system',
#   'content': '당신의 첫 번째 역할은 주어지는 댓글들에서 비속어 또는 욕설을 순화해서 재구성해야 합니다.'},
#  {'role': 'system',
#   'content': '당신의 두 번째 역할은 주어지는 댓글들에서 공격적인 표현이 드러나지 않게 순화해서 재구성해야 합니다.'},
#  {'role': 'system',
#   'content': '당신의 세 번째 역할은 주어지는 댓글들에서 맥락에 맞는 간단한 부드러운 표현을 추가하여 재구성해야 합니다.'},
#  {'role': 'system',
#   'content': '당신은 첫 번째 역할을 수행하고 두 번째 역할을 수행하고 세 번째 역할을 수행해야 합니다.'},
#  {'role': 'system',
#   'content': '사용자가 입력한 댓글을 처리할 때, 올바르게 수행했는지 한번 더 생각하고 재구성 된 댓글을 출력합니다.'},
#  {'role': 'user',
# ...

# %%
step22("댓글1:누가 여자한테 호구되라 협박함? 방생하지말고 자멸해라 여자들이 남자 무시하고 좆으로 보는것도 다 남자가 바보고 여자우대해서 그런거다 페미랑 전직 대통령 탓이다? 풉ㅋㅋㅋ")
# Out:
# [('댓글1:누가 여자한테 호구되라 협박함? 방생하지말고 자멸해라 여자들이 남자 무시하고 좆으로 보는것도 다 남자가 바보고 여자우대해서 그런거다 페미랑 전직 대통령 탓이다? 풉ㅋㅋㅋ',
#   '댓글1:누가 여자한테 호구되라 협박함? 방생하지말고 자멸해라 여자들이 남자 무시하고 좆으로 보는것도 다 남자가 바보고 여자우대해서 그런거다 페미랑 전직 대통령 탓이다? 풉@@@')]
